# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# x = range(0, 100)
# y = [3,3,3,3,3,3,2,1,2,1,2,1,2,1,2,1,2,1,2,1,1,1,1,1,2,1,1,1,1,2]
# plt.plot(x, y)
# plt.show()

# %%
x = range(0,31)
y = [3,3,3,3,3,3,2,1,2,1,2,1,2,1,2,1,2,1,2,1,1,1,1,1,2,1,1,1,1,2,0]
plt.plot(x, y) 
plt.show()

# %%
x = range(0,2)
y = [2,0]
plt.plot(x, y) 
plt.show()

# %%
x = range(0,4)
y = [1,1,2,0]
plt.plot(x, y) 
plt.show()

# %%
xs=[0,0,1,1]
ys=[0,1,0,1]
plt.scatter(xs,ys)


x = np.arange(0, 2)     
y = x/4+1/8
plt.plot(x, y) 
plt.show()

# %%
xs=[0,0,1,1]
ys=[0,1,0,1]
plt.scatter(xs,ys)


x = np.arange(0, 2)     
y = x-1/2
plt.plot(x, y) 
plt.show()

# %%
xs=[0,0,1,1]
ys=[0,1,0,1]
plt.scatter(xs,ys)


x = np.arange(0, 2)     
y = -2*x+2
plt.plot(x, y) 
plt.show()

# %%
xs=[0,0,1,1]
ys=[0,1,0,1]
plt.scatter(xs,ys)


x = np.arange(0, 2)     
y = -x+1/2
plt.plot(x, y) 
plt.show()

# %%
xs=[0,0,1,1]
ys=[0,1,0,1]
plt.scatter(xs,ys)


x = np.arange(0, 2)     
y = -1/5*x+5.5/5

x2 = np.arange(0, 2)     
y2 = -3/8*x2+1/8

plt.plot(x, y)
plt.plot(x2, y2)
plt.show()

# %%
xs=[0,0,1,1]
ys=[0,1,0,1]
plt.scatter(xs,ys)


x = np.arange(0, 2)     
y = -1/6*x2+5/2

x2 = np.arange(0, 2)     
y2 = -1/4*x+1/4

plt.plot(x, y)
plt.plot(x2, y2)
plt.show()

# %%
xs=[0,0,1,1]
ys=[0,1,0,1]
plt.scatter(xs,ys)


x = np.arange(0, 2)     
y = 36*x/84+106/84
plt.plot(x, y) 
plt.show()

# %%
w1=2.1
w2=-0.1
w3=-1.5
w4=-4.4
w5=-2.6
w6=0
w7=0.3
w8=-3
w9=2


x1=[0,0,1,1]
x2=[0,1,0,1]


#y=w7+w8*(w1+w2*x1+w3*x2+w9*(w4+w5*x1+w6*x2)

# %%
xs=[0,0,1,1]
ys=[0,1,0,1]
plt.scatter(xs,ys)


x = np.arange(0, 2)     
y = -x/15+7/5
plt.plot(x, y) 
plt.show()

# %%
xs=[0,0,1,1]
ys=[0,1,0,1]
plt.scatter(xs,ys)


x = np.arange(0, 2)     
y = -x/6+1/2
plt.plot(x, y) 
plt.show()

# %%
x = range(0,3)
y = [2,1,0]
plt.plot(x, y) 
plt.show()

# %%
x = range(0,3)
y = [3,2,0]
plt.plot(x, y) 
plt.show()

# %%
x = range(0,11)
y = [2,2,2,2,3,3,2,3,2,1,0]
plt.plot(x, y) 
plt.show()
