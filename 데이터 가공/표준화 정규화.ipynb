# %%
import pandas as pd
import pandas as pd
import numpy as np
# 기존 plotnine(ggplot)코드를 pandas와 seaborn으로 변경
# from plotnine import *
import seaborn as sns
# 지도 시각화를 위해
import folium

import warnings
warnings.filterwarnings('ignore')
# warning 메시지 제거, warning 메시지는 라이브러리 업데이트나 사용법에 대한 안내 등이 있습니다.
# 코딩을 처음 시작할 때는  warning 메시지가 나오면 당황하실 수도 있어서 제거를 하고 보도록 합니다.
# warning 메시지는 제거하고 보셔도 되지만 Error 메시지를 꼭 고쳐주셔야 합니다.
warnings.filterwarnings('ignore', 'This pattern has match groups')
warnings.filterwarnings('ignore', 'The iterable function was deprecated in Matplotlib')

import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
# Window 의 한글 폰트 설정
# plt.rc('font',family='Malgun Gothic')
# Mac 의 한글 폰트 설정
plt.rc('font',family='Malgun Gothic') 
plt.rc('axes', unicode_minus=False)

set_matplotlib_formats('retina')

import json
import mpld3

# %%
def make_plot(file,col):
    
    path='D:\\사용자\\USER\\Desktop\\데이터\\상권\\'+file+'.csv'
    
    
    library=pd.read_csv(path, encoding='cp949')

    df=library
    df = pd.DataFrame({'group':df['구'], 'values':df[col] })

    # Reorder it based on the values:


    #f = plt.figure(figsize=(6,8))

    # Make the plot
    #plt.hlines(y=my_range, xmin=0, xmax=ordered_df['values'], color='skyblue')
   # plt.plot(ordered_df['values'], my_range, "D",color="violet")
    #plt.yticks(my_range, ordered_df['group'])
    #plt.show()

    #print(mpld3.fig_to_html(f, figid='THIS_IS_FIGID'))
    return df

# %%
seoul_health1=make_plot("서울건강2",'병원')
seoul_health2=make_plot("서울건강2",'산후조리원')
seoul_health3=make_plot("서울건강2",'안마원')
seoul_health4=make_plot("서울건강2",'약국')
seoul_health5=make_plot("서울건강2",'의원')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9475e1eb7396> in <module>
# ----> 1 seoul_health1=make_plot("서울건강2",'병원')
#       2 seoul_health2=make_plot("서울건강2",'산후조리원')
#       3 seoul_health3=make_plot("서울건강2",'안마원')
#       4 seoul_health4=make_plot("서울건강2",'약국')
#       5 seoul_health5=make_plot("서울건강2",'의원')
#
# <ipython-input-2-25dd0fb57a8a> in make_plot(file, col)
#       4
#       5
# ----> 6     library=pd.read_csv(path, encoding='cp949')
#       7
#       8     df=library
#
# ...

# %%
def normal(df):
    data=list(df['values'])
    std_data = (data - np.mean(data,axis = 0))/ np.std(data,axis = 0)
    normalization=(std_data-min(std_data))/(max(std_data)-min(std_data))
    df['values']=normalization
    return df

# %%
d1=normal(seoul_health1)
d2=normal(seoul_health2)
d3=normal(seoul_health3)
d4=normal(seoul_health4)
d5=normal(seoul_health5)
m1=pd.merge(d1, d2 ,on="group")
m2=pd.merge(d3, d4 ,on="group")
m3=pd.merge(m1, m2 ,on="group")
m4=pd.merge(m3, d5 ,on="group")
m4
# Out:
#    group  values_x_x  values_y_x  values_x_y  values_y_y    values
# 0    강남구         1.0    1.000000    0.500000    1.000000  1.000000
# 1    서초구         0.7    0.506494    1.000000    0.326087  0.222222
# 2    종로구         0.5    0.376623    0.333333    0.304348  0.111111
# 3    금천구         0.5    0.116883    0.333333    0.130435  0.555556
# 4    양천구         0.5    0.129870    0.833333    0.130435  0.222222
# 5    송파구         0.5    0.402597    0.500000    0.347826  0.666667
# 6    강동구         0.4    0.142857    0.500000    0.239130  0.222222
# 7    강서구         0.4    0.194805    0.333333    0.173913  0.555556
# 8    구로구         0.4    0.090909    0.666667    0.108696  0.333333
# 9    노원구         0.4    0.129870    0.833333    0.130435  0.111111
# 10   은평구         0.3    0.090909    0.833333    0.130435  0.000000
# 11  영등포구         0.3    0.337662    0.333333    0.282609  0.444444
# 12   마포구         0.3    0.337662    0.333333    0.304348  0.222222
# ...

# %%
m4.to_excel('D:\사용자\\USER\\Desktop\\데이터\\건강\\진짜서울건강.xlsx', index=False)

# %%
def make_plot(file):
    
    path='D:\\사용자\\USER\\Desktop\\데이터\\'+file+'.csv'
    
    
    library=pd.read_csv(path, encoding='cp949')


    df=library

    return df

# %%
dd=make_plot("서울건강")
m5=pd.read_csv('D:\\사용자\\USER\\Desktop\\데이터\\건강\\임시서울건강.csv', encoding='cp949')
m6=pd.merge(dd, m5 ,on="구군")

# %%
m6.to_excel('D:\사용자\\USER\\Desktop\\데이터\\건강\\최종서울건강.xlsx', index=False)

# %%
seoul_health1=make_plot("서울상권",'맥도날드')
seoul_health2=make_plot("서울상권",'스타벅스')
seoul_health3=make_plot("서울상권",'베스킨라빈스')
seoul_health4=make_plot("서울상권",'올리브영')
seoul_health5=make_plot("서울상권",'나이키')

# %%
m4.to_excel('D:\사용자\\USER\\Desktop\\데이터\\상권\\정규화서울상권.xlsx', index=False)
