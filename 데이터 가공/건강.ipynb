# %%
import pandas as pd
import pandas as pd
import numpy as np
# 기존 plotnine(ggplot)코드를 pandas와 seaborn으로 변경
# from plotnine import *
import seaborn as sns
# 지도 시각화를 위해
import folium

import warnings
warnings.filterwarnings('ignore')
# warning 메시지 제거, warning 메시지는 라이브러리 업데이트나 사용법에 대한 안내 등이 있습니다.
# 코딩을 처음 시작할 때는  warning 메시지가 나오면 당황하실 수도 있어서 제거를 하고 보도록 합니다.
# warning 메시지는 제거하고 보셔도 되지만 Error 메시지를 꼭 고쳐주셔야 합니다.
warnings.filterwarnings('ignore', 'This pattern has match groups')
warnings.filterwarnings('ignore', 'The iterable function was deprecated in Matplotlib')

import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
# Window 의 한글 폰트 설정
# plt.rc('font',family='Malgun Gothic')
# Mac 의 한글 폰트 설정
plt.rc('font',family='Malgun Gothic') 
plt.rc('axes', unicode_minus=False)

set_matplotlib_formats('retina')

import json
import mpld3

# %%
def make_plot(file,col):
    
    path='D:\\사용자\\USER\\Desktop\\데이터\\'+file+'.csv'
    
    
    library=pd.read_csv(path, encoding='cp949')
    library = library[library['시도'].notnull() &library['시도'].str.contains('서울특별시')]
    library = library.drop(columns=['시도'],axis=1)
    library= library.sort_values(by=col,ascending=False).reset_index()
    library = library.drop(columns=['index'], axis=1)
    library

    df=library
    df = pd.DataFrame({'group':df['구군'], 'values':df[col] })

    # Reorder it based on the values:
    ordered_df = df.sort_values(by='values')
    my_range=range(1,len(df.index)+1)

    #f = plt.figure(figsize=(6,8))

    # Make the plot
    #plt.hlines(y=my_range, xmin=0, xmax=ordered_df['values'], color='skyblue')
   # plt.plot(ordered_df['values'], my_range, "D",color="violet")
    #plt.yticks(my_range, ordered_df['group'])
    #plt.show()

    #print(mpld3.fig_to_html(f, figid='THIS_IS_FIGID'))
    return df

# %%
seoul_health1=make_plot("전국건강",'인구 십만명당 정신건강증진기관 수')
seoul_health2=make_plot("전국건강",'인구 천명당 의료기관 종사 의사수')
seoul_health3=make_plot("전국건강",'인구 천명당 의료기관병상수')

seoul_edu1=make_plot("전국교육",'교원 1인당 학생수')
seoul_edu2=make_plot("전국교육",'영유아 천명당 보육시설 수')
seoul_edu3=make_plot("전국교육",'인구 십만명당 학교수')
seoul_edu4=make_plot("전국교육",'인구 천명당 사설학원수')

seoul_safe1=make_plot("전국안전",'인구 천명당 cctv 대수')
seoul_safe2=make_plot("전국안전",'인구 십만명당 응급의료기관 및 응급실 운영기관수')
seoul_safe3=make_plot("전국안전",'단위면적당 지역경찰관서 수')


seoul_play1=make_plot("전국여가",'여가활용 만족도')
seoul_play2=make_plot("전국여가",'노인 천명당 노인여가복지시설수')
seoul_play3=make_plot("전국여가",'인구 십만명당 도서관수')
seoul_play4=make_plot("전국여가",'인구 십만명당 문화기반시설수')
seoul_play5=make_plot("전국여가",'인구 천명당 체육관련 여가시설수')

seoul_eco1=make_plot("전국환경",'환경체감도')
seoul_eco2=make_plot("전국환경",'인구 천명당 1일 산업폐수 방류량')
seoul_eco3=make_plot("전국환경",'도시지역 중 녹지지역 비율')
seoul_eco4=make_plot("전국환경",'미세먼지')
seoul_eco5=make_plot("전국환경",'주민 1인당 생활폐기물배출량')

# %%
file="전국건강"


path='D:\\사용자\\USER\\Desktop\\데이터\\'+file+'.csv'
      
health=pd.read_csv(path, encoding='cp949')
health = health[health['시도'].notnull() &health['시도'].str.contains('서울특별시')]

health
# Out:
#     No     시도    구군      평균  인구 십만명당 정신건강증진기관 수  인구 천명당 의료기관 종사 의사수  \
# 0    1  서울특별시   종로구  0.9220              0.6914              1.0000
# 1    2  서울특별시    중구  0.6742              0.4106              0.9995
# 2    3  서울특별시   용산구  0.5898              0.3353              0.6046
# 3    4  서울특별시   성동구  0.4794              0.3321              0.5783
# 4    5  서울특별시   광진구  0.6373              0.7393              0.6352
# 5    6  서울특별시  동대문구  0.6024              0.4476              0.8601
# 6    7  서울특별시   중랑구  0.5225              0.5212              0.4325
# 7    8  서울특별시   성북구  0.4177              0.2942              0.5215
# 8    9  서울특별시   강북구  0.3987              0.4917              0.3996
# 9   10  서울특별시   도봉구  0.4683              0.9137              0.3673
# 10  11  서울특별시   노원구  0.4783              0.3779              0.5734
# 11  12  서울특별시   은평구  0.3925              0.5453              0.3705
# 12  13  서울특별시  서대문구  0.8437              0.6825              0.9286
# ...

# %%
from matplotlib import rc

# y-axis in bold
rc('font', weight='bold')
 
# Values of each group
bars1 = list(health['인구 십만명당 정신건강증진기관 수'])
bars2 = list(health['인구 천명당 의료기관 종사 의사수'])
bars3 = list(health['인구 천명당 의료기관병상수'])
 
# Heights of bars1 + bars2
bars = np.add(bars1, bars2).tolist()
 
# The position of the bars on the x-axis
r = range(25)
 
# Names of group and bar width
names = list(health['구군'])
barWidth = 1

f=plt.figure(figsize=(20,8))

# Create brown bars
plt.bar(r, bars1, color='#99FF99', edgecolor='white', width=barWidth, label='건강')
# Create green bars (middle), on top of the first ones
plt.bar(r, bars2, bottom=bars1, color='#FF33CC', edgecolor='white', width=barWidth, label='교육')
# Create green bars (top)
plt.bar(r, bars3, bottom=bars, color='#9966FF', edgecolor='white', width=barWidth, label='안전')
 
# Custom X axis
plt.xticks(r, names, fontweight='bold')
plt.xlabel("종합")
 
plt.legend() #####################범례추가하기



# Show graphic
plt.show()

#print(mpld3.fig_to_html(f, figid='THIS_IS_FIGID'))

# %%
html=health1.to_html()
#print(html)

# %%
df=seoul_health3


ordered_df = df.sort_values(by='values')
my_range=range(1,len(df.index)+1)

f = plt.figure(figsize=(6,8))

# Make the plot
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['values'], color='skyblue')
plt.plot(ordered_df['values'], my_range, "D",color="violet")
plt.yticks(my_range, ordered_df['group'])


plt.show()

print(mpld3.fig_to_html(f, figid='THIS_IS_FIGID'))
# Out:
# <style>
#
# </style>
#
# <div id="THIS_IS_FIGID"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
seoul_health1.to_excel('D:\사용자\\USER\\Desktop\\데이터\\pr.xlsx', index=False)

# %%
df=pd.read_csv(r'D:\사용자\USER\Desktop\데이터\건강\서울병원.csv', encoding='cp949')
df['구']=''
name_split = df["도로명전체주소"].str.split(" ")
df["구"] = name_split.str.get(1)
df = df.drop(columns=['도로명전체주소','소재지전체주소',], axis=1)
df=df.groupby('구')
df=df.count().reset_index()
df.columns = ['구','병원']
df= df.sort_values(by='병원',ascending=False)
df=df.reset_index()
df = df.drop(columns=['index'], axis=1)
df
# Out:
#        구  병원
# 0    강남구  70
# 1    송파구  41
# 2    강서구  36
# 3    강동구  33
# 4   동대문구  31
# 5   영등포구  30
# 6    서초구  28
# 7    은평구  25
# 8    노원구  22
# 9    구로구  21
# 10   중랑구  20
# 11   도봉구  18
# 12   관악구  18
# 13   강북구  17
# 14   양천구  16
# 15   금천구  15
# 16   성북구  14
# 17   동작구  13
# 18  서대문구  13
# 19   광진구  12
# 20   마포구  12
# 21   성동구  11
# 22    중구  11
# 23   종로구  10
# 24   용산구   3

# %%
def make_table(file,col):
    path='D:\\사용자\\USER\\Desktop\\데이터\\건강\\'+file+'.csv'
    
    df=pd.read_csv(path, encoding='cp949')
    df['구']=''
    name_split = df["도로명전체주소"].str.split(" ")
    df["구"] = name_split.str.get(1)
    df = df.drop(columns=['도로명전체주소','소재지전체주소',], axis=1)
    df=df.groupby('구')
    df=df.count().reset_index()
    df.columns = ['구',col]
    df= df.sort_values(by=col,ascending=False)

    return df

# %%
h1=make_table("서울병원","병원")
h2=make_table("서울산후조리원","산후조리원")

h2['구'][0]='관악구'
h2['산후조리원'][0]='0'

h3=make_table("서울안마원","안마원")
h4=make_table("서울약국","약국")
h5=make_table("서울의원","의원")
m1=pd.merge(h1, h2 ,on="구")
m2=pd.merge(h3, h4 ,on="구")
m3=pd.merge(m1, m2 ,on="구")
m4=pd.merge(m3, h5 ,on="구")

# %%
df=pd.read_csv(r'D:\사용자\USER\Desktop\데이터\건강\서울총인구.csv', encoding='cp949', thousands=',')
df['구']=''
name_split = df["행정구역"].str.split(" ")
df["구"] = name_split.str.get(1)

df = df.drop(columns=['행정구역'], axis=1)

m4=pd.merge(m4, df ,on="구")
m4
# Out:
#        구  병원  산후조리원  안마원   약국    의원     인구수
# 0    강남구  70     16   35  493  2705  532818
# 1    송파구  41      9    8  392  1170  658991
# 2    강서구  36      9   11  262   846  576361
# 3    강동구  33     11    3  255   809  464411
# 4   동대문구  31      6   12  285   580  337857
# 5   영등포구  30      5    8  263   758  377655
# 6    서초구  28      6   12  227  1264  417568
# 7    은평구  25      6    7  221   659  474414
# 8    노원구  22      5    5  230   720  514050
# 9    구로구  21      8    5  187   550  397887
# 10   중랑구  20      3    9  184   518  388911
# 11   도봉구  18      4   11  122   352  319211
# 12   관악구  18      0   13  228   687  488304
# 13   강북구  17      3    8  169   449  301430
# 14   양천구  16      9   13  191   635  449603
# 15   금천구  15      3    5  129   340  230759
# 16   성북구  14      3    6  203   520  432815
# 17   동작구  13      2    7  197   586  387558
# 18  서대문구  13      2    4  150   422  306472
# 19   광진구  12      3    7  150   545  341505
# ...

# %%
m4.to_excel('D:\사용자\\USER\\Desktop\\데이터\\건강\\서울건강.xlsx', index=False)
